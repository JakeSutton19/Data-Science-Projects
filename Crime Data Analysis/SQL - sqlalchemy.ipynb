# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine

# %%
file = "Census_Data.csv"
output = 'output.csv'

# %%
engine = create_engine('sqlite://', echo=False)
df = pd.read_csv(file)

df.to_sql('census', engine, if_exists='replace', index=False)

results = engine.execute('Select * from census')

final=pd.DataFrame(results, columns=df.columns)
final.to_csv(output, index=False)

# %%
final
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
final
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                   19.0      Belmont Cragin                        10.8
# 1                   20.0             Hermosa                         6.9
# 2                   23.0       Humboldt park                        14.8
# 3                   30.0      South Lawndale                        15.2
# 4                   31.0     Lower West Side                         9.6
# 5                   57.0      Archer Heights                         8.5
# 6                   58.0       Brighton Park                        14.4
# 7                   61.0            New City                        11.9
# 8                   62.0         West Elsdon                        11.1
# 9                   63.0           Gage Park                        15.8
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              18.7                         14.6
# ...

# %%
file2 = "Chicago_Crime_Data-v2.csv"
output = 'output2.csv'


engine = create_engine('sqlite://', echo=False)
df = pd.read_csv(file2)
df.to_sql('crime', engine, if_exists='replace', index=False)

results = engine.execute('Select * from crime')

final=pd.DataFrame(results, columns=df.columns)
final.to_csv(output, index=False)
final
# Out:
#            ID CASE_NUMBER                    DATE                     BLOCK  \
# 0     3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1     3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2     8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3     7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4    10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
# ..        ...         ...                     ...                       ...
# 528  10453948    HZ192829  03/01/2016 12:00:00 AM           028XX E 79TH ST
# 529  10397129    HZ133234  01/29/2016 03:30:00 PM       006XX W HARRISON ST
# 530   3269495    HJ747227  11/08/2003 04:54:15 PM           012XX W 81ST ST
# 531  10840565    JA143710  02/06/2017 01:20:00 PM        009XX N KARLOV AVE
# 532   1326195     G021609  01/11/2001 02:30:41 AM       087XX S ESCANABA AV
#
#      IUCR                      PRIMARY_TYPE  \
# ...
