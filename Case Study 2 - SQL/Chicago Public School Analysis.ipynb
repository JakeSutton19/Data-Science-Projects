# %%
#!pip install ipython-sql

# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine

# %%
census_file = "Census_Data.csv"
crime_file = "Chicago_Crime_Data-v2.csv"
school_file = "Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012-v3.csv"
output = 'output.csv'

# %%
engine = create_engine('sqlite://', echo=False)

# %%
df = pd.read_csv(crime_file)
df.to_sql('crime', engine, if_exists='replace', index=False)
sql_action = engine.execute('Select * from crime')

result=pd.DataFrame(sql_action, columns=df.columns)
result.head()
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE       0         0  ...  14.0
# 1                         OTHER       0         0  ...  27.0
# ...

# %% [markdown]
# Problem 1: Find the total number of crimes recorded in the Crime table
#
# Answer

# %%
sql_action = engine.execute('Select COUNT(*) as "Crimes Count" from crime')

result=pd.DataFrame(sql_action)
result
# Out:
#    Crimes Count
# 0           533

# %% [markdown]
# Problem 2: Retrieve first 5 rows from Chicago_Crime_Data
#
# Answer:

# %%
sql_action = engine.execute('Select * from crime LIMIT 5')

result=pd.DataFrame(sql_action, columns=df.columns)
result.head()
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE       0         0  ...  14.0
# 1                         OTHER       0         0  ...  27.0
# ...

# %% [markdown]
# Problem 3: How mamy crimes involve an arrest?
#
# Answer:

# %%
sql_action = engine.execute('Select COUNT(ARREST) as "Arrests Count" from crime \
                            where ARREST > 0')

result=pd.DataFrame(sql_action)
result
# Out:
#    Arrests Count
# 0            163

# %% [markdown]
# Problem 4: Which unique types of crimes have been recorded on Street locations?
#
# Answer:

# %%
sql_action = engine.execute('Select PRIMARY_TYPE as "Types of Crimes on Streets" from crime \
                            where LOCATION_DESCRIPTION = "STREET" \
                            Group By PRIMARY_TYPE')

result=pd.DataFrame(sql_action)
result
# Out:
#           Types of Crimes on Streets
# 0                            ASSAULT
# 1                            BATTERY
# 2                    CRIMINAL DAMAGE
# 3                  CRIMINAL TRESPASS
# 4                 DECEPTIVE PRACTICE
# 5                           HOMICIDE
# 6   INTERFERENCE WITH PUBLIC OFFICER
# 7                         KIDNAPPING
# 8                MOTOR VEHICLE THEFT
# 9                          NARCOTICS
# 10                    NON - CRIMINAL
# 11                     OTHER OFFENSE
# 12                      PROSTITUTION
# 13            PUBLIC PEACE VIOLATION
# 14                           ROBBERY
# 15                       SEX OFFENSE
# 16                             THEFT
# 17                 WEAPONS VIOLATION

# %% [markdown]
# Problem 5: In the Census Data list all community areas whose names start with the letter 'O'
#
# Answer:

# %%
df = pd.read_csv(census_file)
df.to_sql('census', engine, if_exists='replace', index=False)
sql_action = engine.execute('Select * from census')

result=pd.DataFrame(sql_action, columns=df.columns)
result.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
sql_action = engine.execute('Select COMMUNITY_AREA_NAME as "Community Area Names that start with O" from census \
                            where COMMUNITY_AREA_NAME like "O%"')

result=pd.DataFrame(sql_action)
result
# Out:
#   Community Area Names that start with O
# 0                                Oakland
# 1                                 O'Hare

# %% [markdown]
# Problem 6: Which schools in community areas 10 to 35 and have a harship index above 20?
#
# Answer:

# %%
df = pd.read_csv(school_file)
df.to_sql('schools', engine, if_exists='replace', index=False)
sql_action = engine.execute('Select * from schools')

result=pd.DataFrame(sql_action, columns=df.columns)
result.head(5)
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
# 2                                 ES     8010 S Kostner Ave   Chicago    IL
# 3                                 ES     4619 S Wolcott Ave   Chicago    IL
# 4                                 HS        3630 S Wells St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
sql_action = engine.execute('Select COMMUNITY_AREA_NUMBER, NAME_OF_SCHOOL from schools \
                            join census as new_CD on new_CD.COMMUNITY_AREA_NUMBER = schools.COMMUNITY_AREA_NUMBER \
                            where new_CD.COMMUNITY_AREA_NAME between 10 and 35 \
                            and new_CD.HARDSHIP_INDEX > 20')

result=pd.DataFrame(sql_action)
result
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/SCIENCE/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/anaconda3/envs/SCIENCE/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: ambiguous column name: COMMUNITY_AREA_NUMBER
#
# ...
